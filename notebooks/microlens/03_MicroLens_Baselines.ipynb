# %% [markdown]
# # Базовые рекомендательные модели для MicroLens-100K
#
# Цель этапа — реализовать базовые рекомендательные алгоритмы
# и получить исходный уровень качества для дальнейшего сравнения
# с коллаборативными и гибридными моделями.
#
# На данном этапе:
#
# - используется зафиксированное разбиение `train / validation / test`;
# - рекомендации строятся только на основе `train`;
# - уже наблюдавшиеся пользователем объекты исключаются из рекомендаций;
# - качество сначала оценивается на `validation`;
# - используются метрики `Recall@K` и `NDCG@K`;
# - качество дополнительно анализируется для групп
#   `Unseen / Low / Medium / Warm / Hot`.

# %%
import numpy as np
import pandas as pd
import pathlib as Path
